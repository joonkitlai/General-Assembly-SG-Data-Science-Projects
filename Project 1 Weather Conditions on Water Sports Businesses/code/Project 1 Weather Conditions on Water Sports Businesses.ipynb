# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# ### Datasets for analysis
#
# Weather datasets from [data.gov.sg](data.gov.sg):
#
# * [`rainfall-monthly-total.csv`](../data/rainfall-monthly-total.csv): Monthly total rainfall recorded in mm(millimeters) from 1982 to 2022
# * [`rainfall-monthly-number-of-rain-days.csv`](../data/rainfall-monthly-number-of-rain-days.csv): Monthly total number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`sunshine-duration-monthly-mean-daily-duration.csv`](../data/sunshine-duration-monthly-mean-daily-duration.csv): Monthly mean sunshine hours in a day from 1982 to 2022
# * [`surface-air-temperature-monthly-mean-daily-minimum.csv`](../data/surface-air-temperature-monthly-mean-daily-minimum.csv): Monthly mean daily minimum surface air temperature from 1982 to 2022
#
# Visitor Arrivals datasets from [data.gov.sg](data.gov.sg):
#
# * [`total-visitor-international-arrivals-monthly.csv`](../data/total-visitor-international-arrivals-monthly.csv): Monthly international visitor arriavls to Singapore from 1978 to 2015

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Happy Water House (HWH), an outdoor water sports centre located at East Coast Park in Singapore, recognises the need to adapt its business to the weather conditions in Singapore. To minimise the risk of losing customers due to unfavourable weather, such as heavy rain or high temperatures, HWH will introduce indoor water sports activities options to complement their outdoor water sports offerings.
#
# This project aims to explore how might HWH use historical weather data to anticipate demand for water sports activities so to better plan staffing needs and provide a positive experience for all customers. HWH expects the following customer patterns at their outdoor and indoor sports centres:
#
# ***Outdoor sports centre***: higher customer numbers during months with low rainfall, few rainy days, high sunshine duration, and low surface air temperature.
#
# ***Indoor sports centre***: higher customer numbers during months with high rainfall, many rainy days, low sunshine duration, and high surface air temperature.
#
# In addition to weather conditions, HWH expects that the number of customers at both their outdoor and indoor sports centres will also be positively correlated with the total number of international visitors to Singapore in a given month. This is because a significant portion of their past customers are tourists.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Weather conditions can have a significant impact on the business of outdoor water sports centres. For example, during the monsoon season, the weather is typically more unpredictable and there may be heavy rainfall, strong winds, and rough seas, which can make it difficult or even dangerous to participate in water sports.
#
# According to a report from [Channel NewsAsia](https://www.channelnewsasia.com/singapore/safety-sea-monsoon-season-3138611), local outdoor water sports centres are cutting their operating hours and reducing activity zones in view of the monsoon season which typically lasts from December to early March, and from June to September.
#
# Acoording to another report from [Forbes](https://www.forbes.com/sites/jimfoerster/2019/06/28/five-industries-that-rely-on-weather-to-make-decisions/?sh=47ccc5247927), the incorporation of weather forecasts into business plans can help optimise staffing and increase profitability for selected industries by allowing for better planning and preparation.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def mean_value(nums):
    return sum(nums)/len(nums)

# %%
mean_value([1,2,3,4,5,6])
# Out:
# 3.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def stand_dev(nums):
    total = [(num-mean_value(nums))**2 for num in nums]
    return (sum(total)/len(nums))**0.5

# %%
stand_dev([1,2,3,4,5,6])
# Out:
# 1.707825127659933

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:

import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### Import all the datasets

# %%
rainfall = pd.read_csv("../data/rainfall-monthly-total.csv")
rainday = pd.read_csv("../data/rainfall-monthly-number-of-rain-days.csv")
sunshine = pd.read_csv("../data/sunshine-duration-monthly-mean-daily-duration.csv")
airtemp = pd.read_csv("../data/surface-air-temperature-monthly-mean-daily-minimum.csv")
arrival = pd.read_csv("../data/total-visitor-international-arrivals-monthly.csv")

# %% [markdown]
# ### Display first 5 rows of data

# %%
rainfall.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
rainday.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
sunshine.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
airtemp.head()
# Out:
#      month  temp_mean_daily_min
# 0  1982-01                 23.3
# 1  1982-02                 23.9
# 2  1982-03                 24.3
# 3  1982-04                 24.3
# 4  1982-05                 25.2

# %%
arrival.head()
# Out:
#      month  total_international_visitor_arrivals
# 0  1978-01                                167016
# 1  1978-02                                147954
# 2  1978-03                                163199
# 3  1978-04                                162400
# 4  1978-05                                162667

# %% [markdown]
# ### Merge dataframes and drop unnecessary rows

# %%
#Since different weather data are in month format, we can merge them into one single dataframe for easier analysis

temp_weather_df = rainfall.merge(rainday).merge(sunshine).merge(airtemp)

# %%
#Checking merged weather dataframes

temp_weather_df.tail()
# Out:
#        month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs  \
# 483  2022-04           239.6                18                5.2
# 484  2022-05           102.0                12                6.7
# 485  2022-06           211.8                17                4.7
# 486  2022-07           145.2                16                6.2
# 487  2022-08           141.4                15                5.5
#
#      temp_mean_daily_min
# 483                 25.1
# 484                 26.2
# 485                 25.3
# 486                 25.8
# 487                 25.8

# %%
#Merging weather dataframes with arrival dataset

weather_df = temp_weather_df.merge(arrival)

# %%
#Checking final merged dataframes 
#Weather data from Year 2016-2022 are intentionally dropped since we do not have arrival data from 2016-2022

weather_df.tail()
# Out:
#        month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs  \
# 403  2015-08           185.8                11                6.1
# 404  2015-09            61.6                 8                4.3
# 405  2015-10            87.2                 9                4.7
# 406  2015-11            72.6                13                4.8
# 407  2015-12           302.3                19                5.3
#
#      temp_mean_daily_min  total_international_visitor_arrivals
# 403                 26.0                               1445052
# 404                 26.5                               1131967
# 405                 26.1                               1246706
# 406                 25.5                               1193906
# 407                 25.0                               1406193

# %% [markdown]
# ### Check for missing values and datatype, any obvious issues with the observations and fix any errors identified

# %%
#Checking missing values


weather_df.isnull().sum()
# Out:
# month                                   0
# total_rainfall                          0
# no_of_rainy_days                        0
# mean_sunshine_hrs                       0
# temp_mean_daily_min                     0
# total_international_visitor_arrivals    0
# dtype: int64

# %%
#Checking datatype, any individual values preventing other columns from being the appropriate type and any obvious issues with the observations 

weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 408 entries, 0 to 407
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   month                                 408 non-null    object
#  1   total_rainfall                        408 non-null    float64
#  2   no_of_rainy_days                      408 non-null    int64
#  3   mean_sunshine_hrs                     408 non-null    float64
#  4   temp_mean_daily_min                   408 non-null    float64
#  5   total_international_visitor_arrivals  408 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 22.3+ KB

# %% [markdown]
# ### Create a new column for year and month

# %%
#As the month column data is better analyzed as year and month, we will create new columnsfor year and month

#Convert month column to datetime format
weather_df['month']= pd.to_datetime(weather_df['month'],format='%Y-%m')

#Create a new column for year and month
weather_df['year']= weather_df['month'].dt.year
weather_df['month']= weather_df['month'].dt.month

# %%
#Save new dataframe into a new variable 

new_weather_df = weather_df[['year', 'month', 'total_rainfall', 'no_of_rainy_days', 'mean_sunshine_hrs', 'temp_mean_daily_min', 'total_international_visitor_arrivals']]

# %%
#Check new dataframe 

new_weather_df.head()
# Out:
#    year  month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs  \
# 0  1982      1           107.1                10                5.6
# 1  1982      2            27.8                 5                7.6
# 2  1982      3           160.8                11                5.1
# 3  1982      4           157.0                14                4.7
# 4  1982      5           102.2                10                5.8
#
#    temp_mean_daily_min  total_international_visitor_arrivals
# 0                 23.3                                239088
# 1                 23.9                                225008
# 2                 24.3                                235113
# 3                 24.3                                225827
# 4                 25.2                                232737

# %% [markdown]
# ### Rename Columns

# %%
#Column names should be all lowercase, not contain spaces and be unique and informative.

new_weather_df.rename(columns={'no_of_rainy_days': 'rainy_days', 'mean_sunshine_hrs':'sunshine_hrs', 'temp_mean_daily_min':'air_temp', 'total_international_visitor_arrivals':'visitor_arrivals'}, inplace=True)

# %%
#Check renamed column names 

new_weather_df.head()
# Out:
#    year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 0  1982      1           107.1          10           5.6      23.3
# 1  1982      2            27.8           5           7.6      23.9
# 2  1982      3           160.8          11           5.1      24.3
# 3  1982      4           157.0          14           4.7      24.3
# 4  1982      5           102.2          10           5.8      25.2
#
#    visitor_arrivals
# 0            239088
# 1            225008
# 2            235113
# 3            225827
# 4            232737

# %% [markdown]
# ### Save cleaned and merged dataframes as csv files

# %%
new_weather_df.to_csv(path_or_buf='../data/new_weather_df.csv', index=False, header=True)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |total_rainfall|float|rainfall-monthly-total|Monthly total rainfall recorded in mm(millimeters) from 1982 to 2022|
# |rainy_days|integer|rainfall-monthly-number-of-rain-days|Monthly total number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.|
# |sunshine_hrs|float|sunshine-duration-monthly-mean-daily-duration|Monthly mean sunshine hours in a day from 1982 to 2022|
# |air_temp|float|surface-air-temperature-monthly-mean-daily-minimum|Monthly mean daily minimum surface air temperature from 1982 to 2022|
# |visitor_arrival|integer|total-visitor-international-arrivals-monthly|Monthly international visitor arriavls to Singapore from 1978 to 2015|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Summary Statistics

# %%
new_weather_df.describe()
# Out:
#               year       month  total_rainfall  rainy_days  sunshine_hrs  \
# count   408.000000  408.000000      408.000000  408.000000    408.000000
# mean   1998.500000    6.500000      179.913480   13.938725      5.615196
# std       9.822754    3.456291      115.757481    4.848432      1.194547
# min    1982.000000    1.000000        0.200000    1.000000      2.700000
# 25%    1990.000000    3.750000       91.575000   11.000000      4.800000
# 50%    1998.500000    6.500000      159.700000   14.000000      5.600000
# 75%    2007.000000    9.250000      241.125000   18.000000      6.300000
# max    2015.000000   12.000000      765.900000   24.000000      9.300000
#
#          air_temp  visitor_arrivals
# count  408.000000      4.080000e+02
# mean    24.807843      6.465237e+05
# std      0.698463      3.116361e+05
# min     22.900000      1.778080e+05
# 25%     24.300000      4.256060e+05
# 50%     24.750000      5.962740e+05
# 75%     25.300000      8.196250e+05
# ...

# %% [markdown]
# ### Dictionary comprehension to apply standard deviation function to each numeric column in the dataframe

# %%
# Standard Deviation Code from Part 1:

def stand_dev(nums):
    total = [(num-mean_value(nums))**2 for num in nums]
    return (sum(total)/len(nums))**0.5

# %%
# Assigning the output to variable sd as a dictionary where:
    # Each column name is now a key
    # That standard deviation of the column is the value
    #Example Output : {'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}

header = list(new_weather_df.columns)[2:]
rows = [stand_dev(new_weather_df[x]) for x in header]

# %%
sd = {key:value for key,value in zip(header, rows)}
sd
# Out:
# {'total_rainfall': 115.61553401482834,
#  'rainy_days': 4.842486634674101,
#  'sunshine_hrs': 1.193082373429657,
#  'air_temp': 0.6976060288389935,
#  'visitor_arrivals': 311253.9815043929}

# %% [markdown]
# ### Investigate trends in the data

# %% [markdown]
# **Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?**

# %%
new_weather_df.loc[new_weather_df['year'].isin([1990]), :].sort_values('total_rainfall', ascending=False)
# Out:
#      year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 104  1990      9           204.5          17           5.1      24.2
# 107  1990     12           201.1          16           5.5      24.1
# 106  1990     11           180.4          17           4.6      24.7
# 100  1990      5           180.1          11           6.5      25.6
# 96   1990      1           147.4          13           5.3      23.7
# 103  1990      8           146.6          13           5.8      25.1
# 102  1990      7           124.0          12           5.9      24.6
# 101  1990      6           112.6           9           6.3      25.4
# 98   1990      3            94.2           4           8.3      25.0
# 105  1990     10            56.4          12           5.9      24.9
# 99   1990      4            52.4          10           6.3      25.3
# 97   1990      2            24.1           8           8.9      24.9
#
#      visitor_arrivals
# 104            427523
# 107            488768
# ...

# %% [markdown]
# In 1990, September and February has the highest and lowest rainfall, respectively.

# %%
new_weather_df.loc[new_weather_df['year'].isin([2000]), :].sort_values('total_rainfall', ascending=False)
# Out:
#      year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 226  2000     11           385.7          21           3.7      24.7
# 219  2000      4           311.6          20           5.3      24.6
# 216  2000      1           275.2          14           4.0      23.9
# 218  2000      3           238.3          15           5.8      24.3
# 217  2000      2           237.8          18           5.8      23.8
# 227  2000     12           236.0          18           4.2      24.4
# 221  2000      6           157.5          16           4.6      24.7
# 225  2000     10           120.9          14           4.0      24.9
# 222  2000      7           116.1          12           6.5      25.3
# 223  2000      8           113.5          18           5.1      24.8
# 220  2000      5            96.8          10           6.8      25.7
# 224  2000      9            81.1          12           6.2      25.2
#
#      visitor_arrivals
# 226            625618
# 219            636970
# ...

# %% [markdown]
# In 2000, November and September has the highest and lowest rainfall, respectively.

# %%
new_weather_df.loc[new_weather_df['year'].isin([2010]), :].sort_values('total_rainfall', ascending=False)
# Out:
#      year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 342  2010      7           298.5          18           4.6      24.6
# 346  2010     11           278.8          21           5.0      24.2
# 341  2010      6           240.5          19           5.1      25.2
# 338  2010      3           238.0          11           6.1      25.1
# 347  2010     12           181.4          14           3.6      23.9
# 345  2010     10           166.2          17           4.2      25.1
# 339  2010      4           158.5          18           6.2      25.0
# 343  2010      8           158.4          16           5.4      24.6
# 340  2010      5           157.5          17           6.5      25.9
# 344  2010      9           121.5          13           5.7      24.9
# 336  2010      1            69.5          10           7.1      24.4
# 337  2010      2             6.3           4           8.8      25.5
#
#      visitor_arrivals
# 342           1095047
# 346            964170
# ...

# %% [markdown]
# In 2010, July and February has the highest and lowest rainfall, respectively.

# %% [markdown]
# ### Which year have the highest and lowest total rainfall in the date range of analysis?

# %%
new_weather_df.groupby('year')['total_rainfall'].sum().sort_values(ascending=False)
# Out:
# year
# 2007    2886.2
# 2001    2783.1
# 2006    2753.2
# 2013    2748.4
# 1984    2686.7
# 1998    2623.1
# 1988    2598.6
# 1986    2536.1
# 2011    2524.2
# 1989    2463.2
# 1996    2418.0
# 2003    2391.2
# 2000    2370.5
# 1995    2332.6
# 2008    2325.1
# 1992    2260.8
# 1993    2168.7
# 2012    2159.9
# 2004    2136.4
# 1999    2134.0
# 1987    2102.8
# 2010    2075.1
# 1983    1993.7
# 1994    1941.8
# 2005    1930.7
# 2009    1920.9
# 1991    1877.0
# 2002    1748.9
# 1982    1581.7
# 2014    1538.4
# 1990    1523.8
# 1985    1483.9
# 2015    1267.1
# 1997    1118.9
# Name: total_rainfall, dtype: float64

# %% [markdown]
# 2007 and 1997 has the highest and lowest total rainfall, respectively.

# %% [markdown]
# ### Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?

# %%
new_weather_df.loc[new_weather_df['year'].isin([1990]), :].sort_values('rainy_days', ascending=False)
# Out:
#      year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 104  1990      9           204.5          17           5.1      24.2
# 106  1990     11           180.4          17           4.6      24.7
# 107  1990     12           201.1          16           5.5      24.1
# 96   1990      1           147.4          13           5.3      23.7
# 103  1990      8           146.6          13           5.8      25.1
# 102  1990      7           124.0          12           5.9      24.6
# 105  1990     10            56.4          12           5.9      24.9
# 100  1990      5           180.1          11           6.5      25.6
# 99   1990      4            52.4          10           6.3      25.3
# 101  1990      6           112.6           9           6.3      25.4
# 97   1990      2            24.1           8           8.9      24.9
# 98   1990      3            94.2           4           8.3      25.0
#
#      visitor_arrivals
# 104            427523
# 106            448573
# ...

# %% [markdown]
# In 1990, September & November and March has the highest and lowest number of rainy days, respectively.

# %%
new_weather_df.loc[new_weather_df['year'].isin([2000]), :].sort_values('rainy_days', ascending=False)
# Out:
#      year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 226  2000     11           385.7          21           3.7      24.7
# 219  2000      4           311.6          20           5.3      24.6
# 217  2000      2           237.8          18           5.8      23.8
# 223  2000      8           113.5          18           5.1      24.8
# 227  2000     12           236.0          18           4.2      24.4
# 221  2000      6           157.5          16           4.6      24.7
# 218  2000      3           238.3          15           5.8      24.3
# 216  2000      1           275.2          14           4.0      23.9
# 225  2000     10           120.9          14           4.0      24.9
# 222  2000      7           116.1          12           6.5      25.3
# 224  2000      9            81.1          12           6.2      25.2
# 220  2000      5            96.8          10           6.8      25.7
#
#      visitor_arrivals
# 226            625618
# 219            636970
# ...

# %% [markdown]
# In 2000, November and May has the highest and lowest number of rainy days, respectively.

# %%
new_weather_df.loc[new_weather_df['year'].isin([2010]), :].sort_values('rainy_days', ascending=False)
# Out:
#      year  month  total_rainfall  rainy_days  sunshine_hrs  air_temp  \
# 346  2010     11           278.8          21           5.0      24.2
# 341  2010      6           240.5          19           5.1      25.2
# 339  2010      4           158.5          18           6.2      25.0
# 342  2010      7           298.5          18           4.6      24.6
# 340  2010      5           157.5          17           6.5      25.9
# 345  2010     10           166.2          17           4.2      25.1
# 343  2010      8           158.4          16           5.4      24.6
# 347  2010     12           181.4          14           3.6      23.9
# 344  2010      9           121.5          13           5.7      24.9
# 338  2010      3           238.0          11           6.1      25.1
# 336  2010      1            69.5          10           7.1      24.4
# 337  2010      2             6.3           4           8.8      25.5
#
#      visitor_arrivals
# 346            964170
# 341            951032
# ...

# %% [markdown]
# In 2010, November and February has the highest and lowest number of rainy days, respectively.

# %% [markdown]
# ### Which year have the highest and lowest number of rainy days in the date range of analysis?

# %%
new_weather_df.groupby('year')['rainy_days'].sum().sort_values(ascending=False)
# Out:
# year
# 2013    206
# 2007    195
# 2012    191
# 1984    191
# 2011    188
# 2000    188
# 2003    186
# 2001    184
# 2008    182
# 1985    181
# 1995    179
# 2010    178
# 1998    177
# 1999    177
# 2005    175
# 2006    174
# 1986    174
# 1988    173
# 1989    173
# 1996    170
# 2009    166
# 1993    163
# 1992    163
# 1994    160
# 2014    152
# 1987    151
# 2004    147
# 1991    146
# 1983    145
# 1990    142
# 2002    139
# 1982    130
# 2015    125
# 1997    116
# Name: rainy_days, dtype: int64

# %% [markdown]
# 2013 and 1997 has the highest and lowest number of rainy days, respectively.

# %% [markdown]
# ### Are there any outliers months in the dataset?

# %% [markdown]
# Yes, there are outliers months in the datasets of "total_rainfall", "sunshine_hrs" and "visitor_arrivals". More details can be found in the boxplots under the next section.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %% [markdown]
# ### Seaborn's Heatmap to visualise correlations between all numeric features

# %%
# Establish size of figure.
plt.figure(figsize = (16,9))

# Get correlation of variables.
corr = new_weather_df.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)
    
plt.title('Correlation Heatmap between all numeric features');

# %% [markdown]
# The above Correlation Heatmap shows strong correlation between:
#
# - year and visitor_arrivals
# - total_rainfall and sunshine_hrs
# - total_rainfall and rainy_days
# - rainy_days and sunshine_hrs

# %% [markdown]
# ### Histogram Subplots to visualise distribution

# %%
# Distribution of total_rainfall 
plt.figure(figsize = (16,18))

ax1 = plt.subplot(5,1,1) 
ax1.set_title("Distribution of total_rainfall", {"fontsize": 15})
ax1.hist(new_weather_df['total_rainfall'], bins=10)

plt.xlabel("total_rainfall (mm)") 
plt.ylabel("Frequency") 
plt.show()

# Distribution of rainy_days
plt.figure(figsize = (16,18))

ax2 = plt.subplot(5,1,2) 
ax2.set_title("Distribution of rainy_days", {"fontsize": 15})
ax2.hist(new_weather_df['rainy_days'], bins=10)

plt.xlabel("rainy_days (Days)") 
plt.ylabel("Frequency") 
plt.show()

# Distribution of sunshine_hrs
plt.figure(figsize = (16,18))

ax3 = plt.subplot(5,1,3) 
ax3.set_title("Distribution of sunshine_hrs", {"fontsize": 15})
ax3.hist(new_weather_df['sunshine_hrs'], bins=10)

plt.xlabel("sunshine_hrs (Hours)") 
plt.ylabel("Frequency") 
plt.show()

# Distribution of air_temp
plt.figure(figsize = (16,18))

ax4 = plt.subplot(5,1,4) 
ax4.set_title("Distribution of air_temp", {"fontsize": 15})
ax4.hist(new_weather_df['air_temp'], bins=10)

plt.xlabel("air_temp (0C)") 
plt.ylabel("Frequency") 
plt.show()

# Distribution of visitor_arrivals
plt.figure(figsize = (16,18))

ax4 = plt.subplot(5,1,5) 
ax4.set_title("Distribution of visitor_arrivals", {"fontsize": 15})
ax4.hist(new_weather_df['visitor_arrivals'], bins=10)

plt.xlabel("visitor_arrivals (Number of Visitors)") 
plt.ylabel("Frequency") 
plt.show()

# %% [markdown]
# The above Histogram Subplots shows that the:
#
# - Distribution of rainy days, sunshine hours and air temperature are normally distributed.
# - Distribution of total rainfall and visitor arrivals are right-skewed.

# %% [markdown]
# ### Boxplot Subplots to identify outliers

# %%
#boxplot for total_rainfall
plt.figure(figsize = (24,10))
ax1 = plt.subplot(1,5,1) 
sns.boxplot(new_weather_df['total_rainfall'])
ax1.set_title("total_rainfall", {"fontsize": 15})
plt.ylabel("mm") 

#boxplot for rainy_days
ax2 = plt.subplot(1,5,2) 
sns.boxplot(new_weather_df['rainy_days'])
ax2.set_title("rainy_days", {"fontsize": 15})
plt.ylabel("Days") 

#boxplot for sunshine_hrs
ax3 = plt.subplot(1,5,3) 
sns.boxplot(new_weather_df['sunshine_hrs'])
ax3.set_title("sunshine_hrs", {"fontsize": 15})
plt.ylabel("Hours") 

#boxplot for air_temp
ax4 = plt.subplot(1,5,4) 
sns.boxplot(new_weather_df['air_temp'])
ax4.set_title("air_temp", {"fontsize": 15})
plt.ylabel("oC") 

#boxplot for visitor_arrivals
ax5 = plt.subplot(1,5,5) 
sns.boxplot(new_weather_df['visitor_arrivals'])
ax5.set_title("visitor_arrivals", {"fontsize": 15})
plt.ylabel("Number of Visitors")
# Out:
# Text(0, 0.5, 'Number of Visitors')

# %% [markdown]
# The above Boxplot Subplots shows that there are:
#
# - Outliers in the datasets of "total_rainfall", "sunshine_hrs" and "visitor_arrivals".
# - No outliers in the datasets of "rainy_days" and "air_temp".

# %% [markdown]
# ### Pairplots to have an overview of correlations between all numeric features

# %%
sns.pairplot(new_weather_df, corner=True)

# %% [markdown]
# The above Pairplot shows strong correlations between:
#
# - year and visitor_arrivals
# - total_rainfall and sunshine_hrs
# - total_rainfall and rainy_days
# - rainy_days and sunshine_hrs

# %% [markdown]
# ### Scatter plots to view relationships between features

# %% [markdown]
# ***Scatter Plot of total_rainfall against sunshine_hrs***

# %%
plt.figure(figsize = (16, 6))
plt.scatter(new_weather_df['total_rainfall'], new_weather_df['sunshine_hrs'], s=5)

plt.title("Scatter Plot of total_rainfall against sunshine_hrs", fontsize = 20)
plt.ylabel("sunshine_hrs (Hours)", fontsize = 16)
plt.xlabel("total_rainfall (mm)", fontsize = 16);

# %% [markdown]
# The above Scatter plots shows that as the total rainfall (mm) increases, the sunshine hours (Hours) decreases.

# %% [markdown]
# ***Scatter Plot of total_rainfall against rainy_days***

# %%
plt.figure(figsize = (16, 6))
plt.scatter(new_weather_df['total_rainfall'], new_weather_df['rainy_days'], s=5)

plt.title("Scatter Plot of total_rainfall against rainy_days", fontsize = 20)
plt.ylabel("rainy_days (No. of Days)", fontsize = 16)
plt.xlabel("total_rainfall (mm)", fontsize = 16);

# %% [markdown]
# The above Scatter plots shows that as the total rainfall (mm) increases, the number of rainy days also increases.

# %% [markdown]
# ***Scatter Plot of rainy_days against sunshine_hrs***

# %%
plt.figure(figsize = (16, 6))
plt.scatter(new_weather_df['sunshine_hrs'], new_weather_df['rainy_days'], s=5)

plt.title("Scatter Plot of rainy_days against sunshine_hrs", fontsize = 20)
plt.ylabel("rainy_days (No. of Days)", fontsize = 16)
plt.xlabel("sunshine_hrs (Hrs)", fontsize = 16);

# %% [markdown]
# The above Scatter plots shows that as the sunshine hours increases, the number of rainy days decreases.

# %% [markdown]
# ### Additional plots: Bar Plots with Line Chart

# %%
#'total_rainfall'

all_month = list(new_weather_df['month'].unique())

plt.figure(figsize = (16,16))
Mean_total_rainfall = new_weather_df.groupby('month')['total_rainfall'].mean()
ax1 = plt.subplot(5,1,1) 
ax1.set_title("Mean total_rainfall of each month", {"fontsize": 15})
ax1.bar(all_month, Mean_total_rainfall, color=['grey', 'green', 'grey', 'grey', 'grey', 'green', 'grey', 'grey', 'grey', 'grey', 'red', 'red'])
ax1.plot(all_month, Mean_total_rainfall, marker='o', color='black', ms=5)
for x,y in zip(all_month, Mean_total_rainfall):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.xlabel("month") 
plt.ylabel("Mean total_rainfall") 
plt.grid(axis='y')
plt.show()

#'rainy_days'

plt.figure(figsize = (16,16))
Mean_rainy_days = new_weather_df.groupby('month')['rainy_days'].mean()
ax2 = plt.subplot(5,1,2)
ax2.set_title("Mean rainy_days of each month", {"fontsize": 15})
ax2.bar(all_month, Mean_rainy_days, color=['grey', 'green', 'grey', 'grey', 'grey', 'green', 'grey', 'grey', 'grey', 'grey', 'red', 'red'])
ax2.plot(all_month, Mean_rainy_days, marker='o', color='black', ms=5)
for x,y in zip(all_month, Mean_rainy_days):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.xlabel("month") 
plt.ylabel("Mean rainy_days") 
plt.grid(axis='y')
plt.show()

#sunshine_hrs

plt.figure(figsize = (16,16))
Mean_sunshine_hrs = new_weather_df.groupby('month')['sunshine_hrs'].mean()
ax3 = plt.subplot(5,1,3)
ax3.set_title("Mean sunshine_hrs of each month", {"fontsize": 15})
ax3.bar(all_month, Mean_sunshine_hrs, color=['grey', 'red', 'grey', 'grey', 'grey', 'red', 'grey', 'grey', 'grey', 'grey', 'green', 'green'])
ax3.plot(all_month, Mean_sunshine_hrs, marker='o', color='black', ms=5)
for x,y in zip(all_month, Mean_sunshine_hrs):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.xlabel("month") 
plt.ylabel("Mean_sunshine_hrs")
plt.grid(axis='y')
plt.ylim([4, 7.5])
plt.show()

#'air_temp'

plt.figure(figsize = (16,16))
Mean_air_temp = new_weather_df.groupby('month')['air_temp'].mean()
ax4 = plt.subplot(5,1,4)
ax4.set_title("Mean air_temp of each month", {"fontsize": 15})
ax4.bar(all_month, Mean_air_temp, color=['green', 'grey', 'grey', 'grey', 'red', 'red', 'grey', 'grey', 'grey', 'grey', 'grey', 'green'])
ax4.plot(all_month, Mean_air_temp, marker='o', color='black', ms=5)
for x,y in zip(all_month, Mean_air_temp):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.xlabel("month") 
plt.ylabel("Mean air_temp") 
plt.grid(axis='y')
plt.ylim([23.5, 26])
plt.show()

#'visitor_arrivals'

plt.figure(figsize = (16,16))
Mean_visitor_arrivals = new_weather_df.groupby('month')['visitor_arrivals'].mean()
ax5 = plt.subplot(5,1,5)
ax5.set_title("Mean visitor_arrivals of each month", {"fontsize": 15})
ax5.bar(all_month, Mean_visitor_arrivals, color=['grey', 'green', 'grey', 'green', 'grey', 'grey', 'red', 'red', 'green', 'grey', 'grey', 'red'])
ax5.plot(all_month, Mean_visitor_arrivals, marker='o', color='black', ms=5)
for x,y in zip(all_month, Mean_visitor_arrivals):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

plt.xlabel("month") 
plt.ylabel("visitor_arrivals") 
plt.grid(axis='y')
plt.ylim([580000, 740000])
plt.show()

# %% [markdown]
# The above Bar Plots with Line Chart shows that between 1982 to 2015, the average
#
# - Total rainfall and rain days are the highest in the months of November and December while lowest in the month of Feburary and June.
# - Sunshine durations is the lowest in the months of November and December while highest in the month of Feburary and June.
# - Surface air temperature is the highest in the months of May and June while lowest in months of January and December.
# - International visitor arrivals is the highest in the months of July, August and December while lowest in the month of Feburary, April and September.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Outdoor water sport centers can provide unique experiences for visitors, but unfavourable weather can ruin this experience. By using historical weather data to anticipate demand, Happy Water House (HWH) aims to better plan staffing needs and provide a positive experience for all customers. In this way, HWH can stay profitable and ahead of the competition.
#
# Considering all above findings from historical weather data, HWH is suggested to:
#
# - **Increase staff at its Outdoor Sports Centres** in the month of February and June in anticipation of lower rainfall, fewer rainy days, higher sunshine duration, and lower surface air temperature.
#
# - **Reduce staff at its Outdoor Sports Centres** while increasing staff at its Indoor Sports Centres in the month of November and December in anticipation of higher rainfall, higher rainy days, lower sunshine duration, and higher surface air temperature.
#
# - **Encourage staff to clear their annual leave** in the month of February, April and September in anticipation of lower international visitor arrivals while scaling number of staff in the month of July, August and December in anticipation of higher international visitor arrivals.
#
# |Month|Sports Centre with higher Staffing needs|Visitor Arrivals
# |---|---|---|
# |January|-|-|-
# |February|Outdoor|Low ; Leave Clearance
# |March|-|-
# |April|-|Low ; Leave Clearance
# |May|-|-
# |June|Outdoor|-
# |July|-|High ; No Leave Clearance
# |August|-|High ; No Leave Clearance
# |September|-|Low ; Leave Clearance
# |October|-|-
# |November|Indoor|-
# |December|Indoor|High ; No Leave Clearance
#
# ***Future Studies***
#
# 1. To consider the potential shift in weather patterns over a period of more than 30 years (1982-2015) by analysing weather data at the decade level (1982-1992, 1993-2003) as this may misrepresent anticipated demand.
#
# 2. To gather historical visitor expenditure data at HWH and examine correlations with existing datasets to understand the factors that drive the most spending.
